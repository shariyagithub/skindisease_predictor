# %%
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.feature import hog
from skimage import exposure
import matplotlib.pyplot as plt
from PIL import Image
import os,sys
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np
# %matplotlib notebook
from sklearn import svm, metrics, datasets
from sklearn.utils import Bunch
from sklearn.model_selection import GridSearchCV, train_test_split
import skimage

# %%
path=r'./mdenode_resized/'

# %%
dirs=os.listdir(path)

# %%
def save_hog():
    for item in dirs:
        for img in os.listdir(path+item):
            if os.path.isfile(path+item+'/'+img):
                a=path+'/'+item
                im=Image.open(path+item+'/'+img)
                im=np.array(im)
                img_eq=exposure.equalize_hist(im)
                f,e=os.path.splitext(img)
                fd, hog_image = hog(img_eq, orientations=9, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=True, multichannel=True)
                hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10)) 
                plt.imsave(a+f + '_hog.jpg', hog_image_rescaled, cmap='Greys')

# %%
save_hog()
# Out:
# C:\Users\sariy\AppData\Local\Programs\Python\Python312\Lib\site-packages\skimage\_shared\utils.py:445: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 save_hog()
#
# Cell In[7], line 10, in save_hog()
#       8 img_eq=exposure.equalize_hist(im)
#       9 f,e=os.path.splitext(img)
# ---> 10 fd, hog_image = hog(img_eq, orientations=9, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=True, multichannel=True)
#      11 hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))
#      12 plt.imsave(a+f + '_hog.jpg', hog_image_rescaled, cmap='Greys')
#
# ...

# %%
# !pip install scikit-image
# Out:
# ...
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB 991.0 kB/s eta 0:00:13
#    ---------------------------------------- 0.1/12.9 MB 871.5 kB/s eta 0:00:15
#     --------------------------------------- 0.2/12.9 MB 1.1 MB/s eta 0:00:12
#     --------------------------------------- 0.2/12.9 MB 1.1 MB/s eta 0:00:12
#     --------------------------------------- 0.3/12.9 MB 1.1 MB/s eta 0:00:12
#     --------------------------------------- 0.3/12.9 MB 1.1 MB/s eta 0:00:12
#    - -------------------------------------- 0.4/12.9 MB 1.1 MB/s eta 0:00:12
#    - -------------------------------------- 0.4/12.9 MB 1.2 MB/s eta 0:00:11
#    - -------------------------------------- 0.5/12.9 MB 1.1 MB/s eta 0:00:11
#    - -------------------------------------- 0.6/12.9 MB 1.2 MB/s eta 0:00:11
#    - -------------------------------------- 0.6/12.9 MB 1.2 MB/s eta 0:00:11
# ...

# %%
for img in images:
    # Resize image
    img_resized = resize(img, (128, 128))  # example size
    
    # Convert to grayscale if needed
    gray_img = rgb2gray(img_resized)

    # Extract HOG features
    hog_features = hog(
        gray_img,
        orientations=9,
        pixels_per_cell=(16, 16),
        cells_per_block=(2, 2),
        block_norm='L2-Hys'
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 for img in images:
#       2     # Resize image
#       3     img_resized = resize(img, (128, 128))  # example size
#       5     # Convert to grayscale if needed
#
# NameError: name 'images' is not defined

# %%
import os
from skimage.io import imread
from skimage.transform import resize
from skimage.color import rgb2gray
from skimage.feature import hog
import numpy as np

# Set dataset path (update if needed)
dataset_path = "mdenode_resized/"

# Read one image from a class folder (e.g., melanoma)
img_path = os.path.join(dataset_path, "melanoma/melanoma896_resized.jpg")
img = imread(img_path)

# Resize image (example: 128x128)
img_resized = resize(img, (128, 128))

# Convert to grayscale
gray_img = rgb2gray(img_resized)

# Extract HOG features
hog_features = hog(
    gray_img,
    orientations=9,
    pixels_per_cell=(16, 16),
    cells_per_block=(2, 2),
    block_norm='L2-Hys'
)

# ✅ Print length of features to match model input
print("Feature length during training:", len(hog_features))
# Out:
# Feature length during training: 1764

# %%
print("Feature length during training:", len(hog_features))
# Out:
# Feature length during training: 1764
